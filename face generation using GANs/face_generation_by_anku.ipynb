# %% [markdown]
# #Reference https://towardsdatascience.com/celebrity-face-generation-with-deep-convolutional-gans-40b96147a1c9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/img_align_celeba.zip' -d '/content/drive/My Drive/celebb'

# %% [markdown]
# importing library and loading data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import torch 
import torch.nn as nn 
import torch.nn.functional as F 
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms 

# data was extracted to this folder
dataroot='/content/drive/MyDrive/celebb/'
dataset=datasets.ImageFolder(
    root=dataroot,
    transform=transforms.Compose([
        transforms.Resize(32),
        transforms.CenterCrop(32),
        transforms.ToTensor()
        ])
        )

dataloader=DataLoader(dataset,num_workers=0,batch_size=128,shuffle=True)

# %% [markdown]
# printing images from loaded data

# %%
dataiter=iter(dataloader)
images,labels=dataiter.next()

def RGBshow(img):
    img=img.numpy()
    plt.imshow(np.transpose(img,(1,2,0)))
    
plot_only=20
fig=plt.figure(1,figsize=(20,5))
for idx in range(plot_only):
    ax=fig.add_subplot(2,plot_only/2,idx+1,xticks=[],yticks=[])
    RGBshow(images[idx])

# %% [markdown]
# scaling images

# %%
def scale(img):
    img=img*2-1
    return img

scaled_img=scale(images[0])
scaled_img.min(),scaled_img.max()
# Out:
# (tensor(-0.9216), tensor(0.8588))

# %% [markdown]
# convolution layer

# %%
def conv(in_channels,out_channels,kernel_size,stride=2,padding=1,batch_norm=True):
    layers=[]
    conv=nn.Conv2d(in_channels,out_channels,kernel_size,stride,padding,bias=False)

    layers.append(conv)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))

    return nn.Sequential(*layers)

# %% [markdown]
# deconvolution layer

# %%
def deconv(in_channels,out_channels,kernel_size,stride=2,padding=1,batch_norm=True):
    layers=[]
    transpose_conv=nn.ConvTranspose2d(in_channels,out_channels,kernel_size,stride,padding,bias=False)

    layers.append(transpose_conv)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))

    return nn.Sequential(*layers)

# %% [markdown]
# defining discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self,conv_dim):
        super(Discriminator,self).__init__()
        self.conv_dim=conv_dim

        self.conv1=conv(3,conv_dim,4,batch_norm=False)
        self.conv2=conv(conv_dim,conv_dim*2,4,batch_norm=False)
        self.conv3=conv(conv_dim*2,conv_dim*4,4,batch_norm=False)
        self.conv4=conv(conv_dim*4,conv_dim*8,4,batch_norm=False)

        self.fc=nn.Linear(conv_dim*8*2*2,1)


    def forward(self,x):
        x=F.leaky_relu(self.conv1(x),0.2)
        x=F.leaky_relu(self.conv2(x),0.2)
        x=F.leaky_relu(self.conv3(x),0.2)
        x=F.leaky_relu(self.conv4(x),0.2)
        x = x.view(-1, self.conv_dim*8*2*2)
        out=self.fc(x)
        return out

# %% [markdown]
# defining generator

# %%
class Generator(nn.Module):
    def __init__(self,z_size,conv_dim):
        super(Generator,self).__init__()
        self.conv_dim=conv_dim
        self.fc = nn.Linear(z_size,conv_dim*8*2*2)

        self.deconv1 = deconv(conv_dim*8,conv_dim*4,4)
        self.deconv2 = deconv(conv_dim*4,conv_dim*2,4)
        self.deconv3 = deconv(conv_dim*2,conv_dim,4)
        self.deconv4 = deconv(conv_dim,3,4,batch_norm=False)

    def forward(self,x):
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*8, 2, 2)
        x = F.relu(self.deconv1(x))
        x = F.relu(self.deconv2(x))
        x = F.relu(self.deconv3(x))
        x = self.deconv4(x)
        out = F.tanh(x)
        return out

# %%
def weights_init_normal(m):

    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # Applying initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        m.weight.data.normal_(0.0, 0.02)
        
        # The bias terms, if they exist, set to 0
        if hasattr(m, 'bias') and m.bias is not None:
            m.bias.data.zero_()

z_size=100
D=Discriminator(32)
G=Generator(z_size,32)

D.apply(weights_init_normal),G.apply(weights_init_normal)

use_cuda=True
if use_cuda and torch.cuda.is_available():
    D.cuda()
    G.cuda()

print(f"{D}\n\n\n{G}\n\n\nGPU on:{use_cuda and torch.cuda.is_available()}")
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (fc): Linear(in_features=1024, out_features=1, bias=True)
# )
#
#
# Generator(
#   (fc): Linear(in_features=100, out_features=1024, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv4): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )
#
#
# GPU on:True

# %% [markdown]
# defining losses

# %%
def real_loss(D_out):
    batch_size = D_out.size(0)
        
    labels = torch.ones(batch_size) * 0.9

    if use_cuda and torch.cuda.is_available():
            labels = labels.cuda()
    criterion=nn.BCEWithLogitsLoss()
    loss=criterion(D_out.squeeze(),labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
        
    labels = torch.ones(batch_size)

    if use_cuda and torch.cuda.is_available():
            labels = labels.cuda()
    criterion=nn.BCEWithLogitsLoss()
    loss=criterion(D_out.squeeze(),labels)
    return loss    
  
  
d_optimizer = optim.Adam(D.parameters(),lr=0.0002,betas=(0.5,0.999))
g_optimizer = optim.Adam(G.parameters(),lr=0.0002,betas=(0.5,0.999))

# %% [markdown]
# training the model and storing as a pickel file

# %%
import pickle as pkl

def train(D, G, n_epochs, print_every=300):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if use_cuda and torch.cuda.is_available():
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if use_cuda and torch.cuda.is_available():
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(dataloader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            d_optimizer.zero_grad()
            
            if use_cuda and torch.cuda.is_available():
                real_images = real_images.cuda()
                
            # 1. Train the discriminator on real and fake images
            
            # Compute the discriminator losses on real images
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if use_cuda and torch.cuda.is_available():
                z = z.cuda()
            fake_images = G(z)
            
            # Compute the discriminator losses on fake images
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if use_cuda and torch.cuda.is_available():
                z = z.cuda()
            fake_images = G(z)
            
            # Compute the discriminator losses on fake images 
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            
            # perfom backprop
            g_loss.backward()
            g_optimizer.step()


            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses
  
  

n_epochs = 50

# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1628: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/   50] | d_loss: 1.3871 | g_loss: 0.6921
# Epoch [    1/   50] | d_loss: 1.1134 | g_loss: 0.3677
# Epoch [    1/   50] | d_loss: 0.5738 | g_loss: 0.3418
# Epoch [    1/   50] | d_loss: 0.4196 | g_loss: 0.4241
# Epoch [    1/   50] | d_loss: 0.6052 | g_loss: 0.3284
# Epoch [    1/   50] | d_loss: 0.5025 | g_loss: 0.3296
# Epoch [    2/   50] | d_loss: 0.5049 | g_loss: 0.3265
# Epoch [    2/   50] | d_loss: 0.5238 | g_loss: 0.3346
# Epoch [    2/   50] | d_loss: 0.6374 | g_loss: 0.4357
# Epoch [    2/   50] | d_loss: 0.4133 | g_loss: 0.3518
# Epoch [    2/   50] | d_loss: 0.7700 | g_loss: 0.4720
# Epoch [    2/   50] | d_loss: 0.5087 | g_loss: 0.3261
# Epoch [    3/   50] | d_loss: 0.5367 | g_loss: 0.3325
# Epoch [    3/   50] | d_loss: 0.4905 | g_loss: 0.3257
# Epoch [    3/   50] | d_loss: 0.4660 | g_loss: 0.3288
# Epoch [    3/   50] | d_loss: 0.5000 | g_loss: 0.3411
# Epoch [    3/   50] | d_loss: 0.4752 | g_loss: 0.3298
# Epoch [    3/   50] | d_loss: 0.5027 | g_loss: 0.3253
# Epoch [    4/   50] | d_loss: 0.4525 | g_loss: 0.3263
# Epoch [    4/   50] | d_loss: 0.4667 | g_loss: 0.3253
# Epoch [    4/   50] | d_loss: 0.4672 | g_loss: 0.3257
# Epoch [    4/   50] | d_loss: 0.5228 | g_loss: 0.3277
# Epoch [    4/   50] | d_loss: 0.3812 | g_loss: 0.4195
# Epoch [    4/   50] | d_loss: 0.4677 | g_loss: 0.3260
# Epoch [    5/   50] | d_loss: 0.6337 | g_loss: 0.3855
# Epoch [    5/   50] | d_loss: 0.4922 | g_loss: 0.3265
# Epoch [    5/   50] | d_loss: 0.4829 | g_loss: 0.3258
# Epoch [    5/   50] | d_loss: 0.4383 | g_loss: 0.3270
# Epoch [    5/   50] | d_loss: 0.4582 | g_loss: 0.3253
# Epoch [    5/   50] | d_loss: 0.5244 | g_loss: 0.3476
# Epoch [    6/   50] | d_loss: 0.4559 | g_loss: 0.3255
# Epoch [    6/   50] | d_loss: 0.4565 | g_loss: 0.3252
# Epoch [    6/   50] | d_loss: 0.4515 | g_loss: 0.3252
# Epoch [    6/   50] | d_loss: 0.4996 | g_loss: 0.3256
# Epoch [    6/   50] | d_loss: 0.4612 | g_loss: 0.3251
# Epoch [    6/   50] | d_loss: 0.4514 | g_loss: 0.3251
# Epoch [    7/   50] | d_loss: 0.4498 | g_loss: 0.3257
# Epoch [    7/   50] | d_loss: 0.4397 | g_loss: 0.3252
# Epoch [    7/   50] | d_loss: 0.4360 | g_loss: 0.3252
# Epoch [    7/   50] | d_loss: 0.4429 | g_loss: 0.3251
# Epoch [    7/   50] | d_loss: 0.4409 | g_loss: 0.3251
# Epoch [    7/   50] | d_loss: 0.4596 | g_loss: 0.3270
# Epoch [    8/   50] | d_loss: 0.4497 | g_loss: 0.3259
# Epoch [    8/   50] | d_loss: 0.4350 | g_loss: 0.3251
# Epoch [    8/   50] | d_loss: 0.4375 | g_loss: 0.3251
# Epoch [    8/   50] | d_loss: 0.4379 | g_loss: 0.3251
# Epoch [    8/   50] | d_loss: 0.4406 | g_loss: 0.3251
# Epoch [    8/   50] | d_loss: 0.4330 | g_loss: 0.3251
# Epoch [    9/   50] | d_loss: 0.4359 | g_loss: 0.3251
# Epoch [    9/   50] | d_loss: 0.4300 | g_loss: 0.3252
# Epoch [    9/   50] | d_loss: 0.4238 | g_loss: 0.3254
# Epoch [    9/   50] | d_loss: 0.4235 | g_loss: 0.3257
# Epoch [    9/   50] | d_loss: 0.4215 | g_loss: 0.3268
# Epoch [    9/   50] | d_loss: 0.4180 | g_loss: 0.3272
# Epoch [   10/   50] | d_loss: 0.4142 | g_loss: 0.3275
# Epoch [   10/   50] | d_loss: 0.4118 | g_loss: 0.3292
# Epoch [   10/   50] | d_loss: 0.4100 | g_loss: 0.3297
# Epoch [   10/   50] | d_loss: 0.4045 | g_loss: 0.3326
# Epoch [   10/   50] | d_loss: 0.4010 | g_loss: 0.3347
# Epoch [   10/   50] | d_loss: 0.4007 | g_loss: 0.3329
# Epoch [   11/   50] | d_loss: 0.3995 | g_loss: 0.3340
# Epoch [   11/   50] | d_loss: 0.4019 | g_loss: 0.3356
# Epoch [   11/   50] | d_loss: 0.4010 | g_loss: 0.3367
# Epoch [   11/   50] | d_loss: 0.3992 | g_loss: 0.3361
# Epoch [   11/   50] | d_loss: 0.3957 | g_loss: 0.3414
# Epoch [   11/   50] | d_loss: 0.3962 | g_loss: 0.3433
# Epoch [   12/   50] | d_loss: 0.4000 | g_loss: 0.3393
# Epoch [   12/   50] | d_loss: 0.3945 | g_loss: 0.3424
# Epoch [   12/   50] | d_loss: 0.3972 | g_loss: 0.3442
# Epoch [   12/   50] | d_loss: 0.3980 | g_loss: 0.3461
# Epoch [   12/   50] | d_loss: 0.3960 | g_loss: 0.3434
# Epoch [   12/   50] | d_loss: 0.3998 | g_loss: 0.3475
# Epoch [   13/   50] | d_loss: 0.3903 | g_loss: 0.3522
# Epoch [   13/   50] | d_loss: 0.3924 | g_loss: 0.3562
# Epoch [   13/   50] | d_loss: 0.3919 | g_loss: 0.3553
# Epoch [   13/   50] | d_loss: 0.3650 | g_loss: 0.3991
# Epoch [   13/   50] | d_loss: 0.3816 | g_loss: 0.3591
# Epoch [   13/   50] | d_loss: 0.3796 | g_loss: 0.3551
# Epoch [   14/   50] | d_loss: 0.3741 | g_loss: 0.3597
# Epoch [   14/   50] | d_loss: 0.3794 | g_loss: 0.3547
# Epoch [   14/   50] | d_loss: 0.3786 | g_loss: 0.3519
# Epoch [   14/   50] | d_loss: 0.3818 | g_loss: 0.3555
# Epoch [   14/   50] | d_loss: 0.3809 | g_loss: 0.3641
# Epoch [   14/   50] | d_loss: 0.3900 | g_loss: 0.3782
# Epoch [   15/   50] | d_loss: 0.3844 | g_loss: 0.3625
# Epoch [   15/   50] | d_loss: 0.3872 | g_loss: 0.3535
# Epoch [   15/   50] | d_loss: 0.3898 | g_loss: 0.3707
# Epoch [   15/   50] | d_loss: 0.3916 | g_loss: 0.3599
# Epoch [   15/   50] | d_loss: 0.3960 | g_loss: 0.3611
# Epoch [   15/   50] | d_loss: 0.3937 | g_loss: 0.3592
# Epoch [   16/   50] | d_loss: 0.3919 | g_loss: 0.3543
# Epoch [   16/   50] | d_loss: 0.3933 | g_loss: 0.3620
# Epoch [   16/   50] | d_loss: 0.3925 | g_loss: 0.3509
# Epoch [   16/   50] | d_loss: 0.3922 | g_loss: 0.3568
# Epoch [   16/   50] | d_loss: 0.3961 | g_loss: 0.3598
# Epoch [   16/   50] | d_loss: 0.3980 | g_loss: 0.3523
# Epoch [   17/   50] | d_loss: 0.3981 | g_loss: 0.3532
# Epoch [   17/   50] | d_loss: 0.3932 | g_loss: 0.3578
# Epoch [   17/   50] | d_loss: 0.3893 | g_loss: 0.3635
# Epoch [   17/   50] | d_loss: 0.3977 | g_loss: 0.3581
# Epoch [   17/   50] | d_loss: 0.3984 | g_loss: 0.3471
# Epoch [   17/   50] | d_loss: 0.3957 | g_loss: 0.3658
# Epoch [   18/   50] | d_loss: 0.3980 | g_loss: 0.3627
# Epoch [   18/   50] | d_loss: 0.3957 | g_loss: 0.3517
# Epoch [   18/   50] | d_loss: 0.3906 | g_loss: 0.3559
# Epoch [   18/   50] | d_loss: 0.3940 | g_loss: 0.3640
# Epoch [   18/   50] | d_loss: 0.3905 | g_loss: 0.3575
# Epoch [   18/   50] | d_loss: 0.3929 | g_loss: 0.3550
# Epoch [   19/   50] | d_loss: 0.3920 | g_loss: 0.3689
# Epoch [   19/   50] | d_loss: 0.3919 | g_loss: 0.3533
# Epoch [   19/   50] | d_loss: 0.3933 | g_loss: 0.3548
# Epoch [   19/   50] | d_loss: 0.3940 | g_loss: 0.3547
# Epoch [   19/   50] | d_loss: 0.4007 | g_loss: 0.3617
# Epoch [   19/   50] | d_loss: 0.3913 | g_loss: 0.3550
# Epoch [   20/   50] | d_loss: 0.3895 | g_loss: 0.3667
# Epoch [   20/   50] | d_loss: 0.3926 | g_loss: 0.3575
# Epoch [   20/   50] | d_loss: 0.3894 | g_loss: 0.3544
# Epoch [   20/   50] | d_loss: 0.3878 | g_loss: 0.3566
# Epoch [   20/   50] | d_loss: 0.3927 | g_loss: 0.3726
# Epoch [   20/   50] | d_loss: 0.3892 | g_loss: 0.3573
# Epoch [   21/   50] | d_loss: 0.3875 | g_loss: 0.3613
# Epoch [   21/   50] | d_loss: 0.3885 | g_loss: 0.3626
# Epoch [   21/   50] | d_loss: 0.3884 | g_loss: 0.3543
# Epoch [   21/   50] | d_loss: 0.3893 | g_loss: 0.3593
# Epoch [   21/   50] | d_loss: 0.3885 | g_loss: 0.3591
# Epoch [   21/   50] | d_loss: 0.3893 | g_loss: 0.3569
# Epoch [   22/   50] | d_loss: 0.3905 | g_loss: 0.3531
# Epoch [   22/   50] | d_loss: 0.3854 | g_loss: 0.3633
# Epoch [   22/   50] | d_loss: 0.3874 | g_loss: 0.3558
# Epoch [   22/   50] | d_loss: 0.3864 | g_loss: 0.3597
# Epoch [   22/   50] | d_loss: 0.3842 | g_loss: 0.3624
# Epoch [   22/   50] | d_loss: 0.3861 | g_loss: 0.3569
# Epoch [   23/   50] | d_loss: 0.3891 | g_loss: 0.3653
# Epoch [   23/   50] | d_loss: 0.3824 | g_loss: 0.3659
# Epoch [   23/   50] | d_loss: 0.3861 | g_loss: 0.3746
# Epoch [   23/   50] | d_loss: 0.3856 | g_loss: 0.3630
# Epoch [   23/   50] | d_loss: 0.3841 | g_loss: 0.3637
# Epoch [   23/   50] | d_loss: 0.3895 | g_loss: 0.3765
# Epoch [   24/   50] | d_loss: 0.3870 | g_loss: 0.3681
# Epoch [   24/   50] | d_loss: 0.3852 | g_loss: 0.3622
# Epoch [   24/   50] | d_loss: 0.3847 | g_loss: 0.3668
# Epoch [   24/   50] | d_loss: 0.3833 | g_loss: 0.3852
# Epoch [   24/   50] | d_loss: 0.3808 | g_loss: 0.3558
# Epoch [   24/   50] | d_loss: 0.3822 | g_loss: 0.3691
# Epoch [   25/   50] | d_loss: 0.3818 | g_loss: 0.3679
# Epoch [   25/   50] | d_loss: 0.3830 | g_loss: 0.3629
# Epoch [   25/   50] | d_loss: 0.3792 | g_loss: 0.3774
# Epoch [   25/   50] | d_loss: 0.3785 | g_loss: 0.3727
# Epoch [   25/   50] | d_loss: 0.3813 | g_loss: 0.3672
# Epoch [   25/   50] | d_loss: 0.3826 | g_loss: 0.3704
# Epoch [   26/   50] | d_loss: 0.3836 | g_loss: 0.3760
# Epoch [   26/   50] | d_loss: 0.3832 | g_loss: 0.3686
# Epoch [   26/   50] | d_loss: 0.3805 | g_loss: 0.3721
# Epoch [   26/   50] | d_loss: 0.3805 | g_loss: 0.3894
# Epoch [   26/   50] | d_loss: 0.3839 | g_loss: 0.3689
# Epoch [   26/   50] | d_loss: 0.3814 | g_loss: 0.3828
# Epoch [   27/   50] | d_loss: 0.3804 | g_loss: 0.3831
# Epoch [   27/   50] | d_loss: 0.3802 | g_loss: 0.3714
# Epoch [   27/   50] | d_loss: 0.3795 | g_loss: 0.3734
# Epoch [   27/   50] | d_loss: 0.3780 | g_loss: 0.3682
# Epoch [   27/   50] | d_loss: 0.3831 | g_loss: 0.3653
# Epoch [   27/   50] | d_loss: 0.3796 | g_loss: 0.3783
# Epoch [   28/   50] | d_loss: 0.3860 | g_loss: 0.3976
# Epoch [   28/   50] | d_loss: 0.3779 | g_loss: 0.3755
# Epoch [   28/   50] | d_loss: 0.3740 | g_loss: 0.3802
# Epoch [   28/   50] | d_loss: 0.3778 | g_loss: 0.3816
# Epoch [   28/   50] | d_loss: 0.3769 | g_loss: 0.3846
# Epoch [   28/   50] | d_loss: 0.3791 | g_loss: 0.3943
# Epoch [   29/   50] | d_loss: 0.3757 | g_loss: 0.3814
# Epoch [   29/   50] | d_loss: 0.3810 | g_loss: 0.3867
# Epoch [   29/   50] | d_loss: 0.3771 | g_loss: 0.3861
# Epoch [   29/   50] | d_loss: 0.3765 | g_loss: 0.3842
# Epoch [   29/   50] | d_loss: 0.3763 | g_loss: 0.3884
# Epoch [   29/   50] | d_loss: 0.3746 | g_loss: 0.3844
# Epoch [   30/   50] | d_loss: 0.3724 | g_loss: 0.3767
# Epoch [   30/   50] | d_loss: 0.3717 | g_loss: 0.3810
# Epoch [   30/   50] | d_loss: 0.3782 | g_loss: 0.3780
# Epoch [   30/   50] | d_loss: 0.3776 | g_loss: 0.3815
# Epoch [   30/   50] | d_loss: 0.3723 | g_loss: 0.3881
# Epoch [   30/   50] | d_loss: 0.3745 | g_loss: 0.3948
# Epoch [   31/   50] | d_loss: 0.3708 | g_loss: 0.4175
# Epoch [   31/   50] | d_loss: 0.3746 | g_loss: 0.3821
# Epoch [   31/   50] | d_loss: 0.3803 | g_loss: 0.3780
# Epoch [   31/   50] | d_loss: 0.3765 | g_loss: 0.3815
# Epoch [   31/   50] | d_loss: 0.3722 | g_loss: 0.3851
# Epoch [   31/   50] | d_loss: 0.3749 | g_loss: 0.3913
# Epoch [   32/   50] | d_loss: 0.3760 | g_loss: 0.3819
# Epoch [   32/   50] | d_loss: 0.3751 | g_loss: 0.3928
# Epoch [   32/   50] | d_loss: 0.3700 | g_loss: 0.3854
# Epoch [   32/   50] | d_loss: 0.3797 | g_loss: 0.3810
# Epoch [   32/   50] | d_loss: 0.3753 | g_loss: 0.3931
# Epoch [   32/   50] | d_loss: 0.3741 | g_loss: 0.3830
# Epoch [   33/   50] | d_loss: 0.3738 | g_loss: 0.3961
# Epoch [   33/   50] | d_loss: 0.3773 | g_loss: 0.3723
# Epoch [   33/   50] | d_loss: 0.3756 | g_loss: 0.3830
# Epoch [   33/   50] | d_loss: 0.3754 | g_loss: 0.3845
# Epoch [   33/   50] | d_loss: 0.3756 | g_loss: 0.3805
# Epoch [   33/   50] | d_loss: 0.3741 | g_loss: 0.3851
# Epoch [   34/   50] | d_loss: 0.3720 | g_loss: 0.3911
# Epoch [   34/   50] | d_loss: 0.3729 | g_loss: 0.3853
# Epoch [   34/   50] | d_loss: 0.3769 | g_loss: 0.3930
# Epoch [   34/   50] | d_loss: 0.3751 | g_loss: 0.3793
# Epoch [   34/   50] | d_loss: 0.3708 | g_loss: 0.3998
# Epoch [   34/   50] | d_loss: 0.3706 | g_loss: 0.3993
# Epoch [   35/   50] | d_loss: 0.3837 | g_loss: 0.3723
# Epoch [   35/   50] | d_loss: 0.3686 | g_loss: 0.3952
# Epoch [   35/   50] | d_loss: 0.3737 | g_loss: 0.4025
# Epoch [   35/   50] | d_loss: 0.3684 | g_loss: 0.4023
# Epoch [   35/   50] | d_loss: 0.3672 | g_loss: 0.4146
# Epoch [   35/   50] | d_loss: 0.3717 | g_loss: 0.3882
# Epoch [   36/   50] | d_loss: 0.3707 | g_loss: 0.4004
# Epoch [   36/   50] | d_loss: 0.3713 | g_loss: 0.4275
# Epoch [   36/   50] | d_loss: 0.3676 | g_loss: 0.4001
# Epoch [   36/   50] | d_loss: 0.3698 | g_loss: 0.4066
# Epoch [   36/   50] | d_loss: 0.3715 | g_loss: 0.3926
# Epoch [   36/   50] | d_loss: 0.3678 | g_loss: 0.4050
# Epoch [   37/   50] | d_loss: 0.3725 | g_loss: 0.3972
# Epoch [   37/   50] | d_loss: 0.3701 | g_loss: 0.3895
# Epoch [   37/   50] | d_loss: 0.3660 | g_loss: 0.3992
# Epoch [   37/   50] | d_loss: 0.3677 | g_loss: 0.3966
# Epoch [   37/   50] | d_loss: 0.3701 | g_loss: 0.3941
# Epoch [   37/   50] | d_loss: 0.3812 | g_loss: 0.4349
# Epoch [   38/   50] | d_loss: 0.3702 | g_loss: 0.3951
# Epoch [   38/   50] | d_loss: 0.3682 | g_loss: 0.4208
# Epoch [   38/   50] | d_loss: 0.3702 | g_loss: 0.4143
# Epoch [   38/   50] | d_loss: 0.3657 | g_loss: 0.4248
# Epoch [   38/   50] | d_loss: 0.3691 | g_loss: 0.4179
# Epoch [   38/   50] | d_loss: 0.3680 | g_loss: 0.3949
# Epoch [   39/   50] | d_loss: 0.3714 | g_loss: 0.4018
# Epoch [   39/   50] | d_loss: 0.3689 | g_loss: 0.3897
# Epoch [   39/   50] | d_loss: 0.3775 | g_loss: 0.4379
# Epoch [   39/   50] | d_loss: 0.3697 | g_loss: 0.3972
# Epoch [   39/   50] | d_loss: 0.3731 | g_loss: 0.3819
# Epoch [   39/   50] | d_loss: 0.3682 | g_loss: 0.4053
# Epoch [   40/   50] | d_loss: 0.3732 | g_loss: 0.4102
# Epoch [   40/   50] | d_loss: 0.3706 | g_loss: 0.4158
# Epoch [   40/   50] | d_loss: 0.3717 | g_loss: 0.3897
# Epoch [   40/   50] | d_loss: 0.3658 | g_loss: 0.3978
# Epoch [   40/   50] | d_loss: 0.3695 | g_loss: 0.4230
# Epoch [   40/   50] | d_loss: 0.3686 | g_loss: 0.3949
# Epoch [   41/   50] | d_loss: 0.3655 | g_loss: 0.3978
# Epoch [   41/   50] | d_loss: 0.3644 | g_loss: 0.4124
# Epoch [   41/   50] | d_loss: 0.3644 | g_loss: 0.4140
# Epoch [   41/   50] | d_loss: 0.3700 | g_loss: 0.4264
# Epoch [   41/   50] | d_loss: 0.3660 | g_loss: 0.3993
# Epoch [   41/   50] | d_loss: 0.3690 | g_loss: 0.4298
# Epoch [   42/   50] | d_loss: 0.3666 | g_loss: 0.4242
# Epoch [   42/   50] | d_loss: 0.3685 | g_loss: 0.3853
# Epoch [   42/   50] | d_loss: 0.3654 | g_loss: 0.4062
# Epoch [   42/   50] | d_loss: 0.3668 | g_loss: 0.4063
# Epoch [   42/   50] | d_loss: 0.3648 | g_loss: 0.3975
# Epoch [   42/   50] | d_loss: 0.3726 | g_loss: 0.3950
# Epoch [   43/   50] | d_loss: 0.3617 | g_loss: 0.4115
# Epoch [   43/   50] | d_loss: 0.3656 | g_loss: 0.4147
# Epoch [   43/   50] | d_loss: 0.3630 | g_loss: 0.4286
# Epoch [   43/   50] | d_loss: 0.3682 | g_loss: 0.3972
# Epoch [   43/   50] | d_loss: 0.3651 | g_loss: 0.4072
# Epoch [   43/   50] | d_loss: 0.3654 | g_loss: 0.3970
# Epoch [   44/   50] | d_loss: 0.3682 | g_loss: 0.4296
# Epoch [   44/   50] | d_loss: 0.3627 | g_loss: 0.4188
# Epoch [   44/   50] | d_loss: 0.3660 | g_loss: 0.4164
# Epoch [   44/   50] | d_loss: 0.3666 | g_loss: 0.4119
# Epoch [   44/   50] | d_loss: 0.3717 | g_loss: 0.4358
# Epoch [   44/   50] | d_loss: 0.3726 | g_loss: 0.3884
# Epoch [   45/   50] | d_loss: 0.3635 | g_loss: 0.3944
# Epoch [   45/   50] | d_loss: 0.3656 | g_loss: 0.4209
# Epoch [   45/   50] | d_loss: 0.3631 | g_loss: 0.4207
# Epoch [   45/   50] | d_loss: 0.3717 | g_loss: 0.3982
# Epoch [   45/   50] | d_loss: 0.3649 | g_loss: 0.4103
# Epoch [   45/   50] | d_loss: 0.3558 | g_loss: 0.4543
# Epoch [   46/   50] | d_loss: 0.3671 | g_loss: 0.4013
# Epoch [   46/   50] | d_loss: 0.3639 | g_loss: 0.4041
# Epoch [   46/   50] | d_loss: 0.3645 | g_loss: 0.4149
# Epoch [   46/   50] | d_loss: 0.3664 | g_loss: 0.4096
# Epoch [   46/   50] | d_loss: 0.3649 | g_loss: 0.4316
# Epoch [   46/   50] | d_loss: 0.3637 | g_loss: 0.4248
# Epoch [   47/   50] | d_loss: 0.3631 | g_loss: 0.4529
# Epoch [   47/   50] | d_loss: 0.3654 | g_loss: 0.4083
# Epoch [   47/   50] | d_loss: 0.3648 | g_loss: 0.4340
# Epoch [   47/   50] | d_loss: 0.3649 | g_loss: 0.4359
# Epoch [   47/   50] | d_loss: 0.3689 | g_loss: 0.4137
# Epoch [   47/   50] | d_loss: 0.3660 | g_loss: 0.4171
# Epoch [   48/   50] | d_loss: 0.3689 | g_loss: 0.4165
# Epoch [   48/   50] | d_loss: 0.3635 | g_loss: 0.4306
# Epoch [   48/   50] | d_loss: 0.3645 | g_loss: 0.4281
# Epoch [   48/   50] | d_loss: 0.3662 | g_loss: 0.3958
# Epoch [   48/   50] | d_loss: 0.3647 | g_loss: 0.4394
# Epoch [   48/   50] | d_loss: 0.3633 | g_loss: 0.4484
# Epoch [   49/   50] | d_loss: 0.3607 | g_loss: 0.4440
# Epoch [   49/   50] | d_loss: 0.3641 | g_loss: 0.4249
# Epoch [   49/   50] | d_loss: 0.3623 | g_loss: 0.4144
# Epoch [   49/   50] | d_loss: 0.3618 | g_loss: 0.4369
# Epoch [   49/   50] | d_loss: 0.3625 | g_loss: 0.4306
# Epoch [   49/   50] | d_loss: 0.3680 | g_loss: 0.4165
# Epoch [   50/   50] | d_loss: 0.3660 | g_loss: 0.4275
# Epoch [   50/   50] | d_loss: 0.3612 | g_loss: 0.4275
# Epoch [   50/   50] | d_loss: 0.3630 | g_loss: 0.4268
# Epoch [   50/   50] | d_loss: 0.3646 | g_loss: 0.4094
# Epoch [   50/   50] | d_loss: 0.3587 | g_loss: 0.4342
# Epoch [   50/   50] | d_loss: 0.3652 | g_loss: 0.4285

# %% [markdown]
# plotting losses

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# generating images as asked in the question

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img +1)*255 / (2)).astype(np.uint8) # rescale to pixel range (0-255)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))
        

# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)
_ = view_samples(-1, samples)
